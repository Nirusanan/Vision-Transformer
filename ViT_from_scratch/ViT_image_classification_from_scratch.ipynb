# %%
! pip install -q "gdown==5.2.0"

# %%
import matplotlib.pyplot as plt
import torch
import torchvision

from torch import nn
from torchvision import transforms

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# !gdown --id 12gG7lbt4JSS5Wy5J33fMaZqDgqio5ejJ
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=12gG7lbt4JSS5Wy5J33fMaZqDgqio5ejJ
# From (redirected): https://drive.google.com/uc?id=12gG7lbt4JSS5Wy5J33fMaZqDgqio5ejJ&confirm=t&uuid=25734f1b-bd05-4340-a39c-3d8ecc45de07
# To: /content/cats-dogs.zip
# 100% 66.7M/66.7M [00:04<00:00, 16.7MB/s]

# %%
# !unzip cats-dogs.zip
# Out:
# Archive:  cats-dogs.zip
#    creating: cats-dogs/test/
#    creating: cats-dogs/test/cats/
#   inflating: cats-dogs/test/cats/cat_1.jpg
#   inflating: cats-dogs/test/cats/cat_106.jpg
#   inflating: cats-dogs/test/cats/cat_109.jpg
#   inflating: cats-dogs/test/cats/cat_113.jpg
#   inflating: cats-dogs/test/cats/cat_114.jpg
#   inflating: cats-dogs/test/cats/cat_116.jpg
#   inflating: cats-dogs/test/cats/cat_118.jpg
#   inflating: cats-dogs/test/cats/cat_119.jpg
#   inflating: cats-dogs/test/cats/cat_124.jpg
#   inflating: cats-dogs/test/cats/cat_140.jpg
#   inflating: cats-dogs/test/cats/cat_147.jpg
#   inflating: cats-dogs/test/cats/cat_156.jpg
#   inflating: cats-dogs/test/cats/cat_158.jpg
#   inflating: cats-dogs/test/cats/cat_162.jpg
#   inflating: cats-dogs/test/cats/cat_18.jpg
#   inflating: cats-dogs/test/cats/cat_190.jpg
#   inflating: cats-dogs/test/cats/cat_203.jpg
#   inflating: cats-dogs/test/cats/cat_223.jpg
#   inflating: cats-dogs/test/cats/cat_234.jpg
#   inflating: cats-dogs/test/cats/cat_244.jpg
#   inflating: cats-dogs/test/cats/cat_251.jpg
#   inflating: cats-dogs/test/cats/cat_255.jpg
#   inflating: cats-dogs/test/cats/cat_268.jpg
#   inflating: cats-dogs/test/cats/cat_279.jpg
#   inflating: cats-dogs/test/cats/cat_281.jpg
#   inflating: cats-dogs/test/cats/cat_290.jpg
#   inflating: cats-dogs/test/cats/cat_306.jpg
#   inflating: cats-dogs/test/cats/cat_313.jpg
#   inflating: cats-dogs/test/cats/cat_332.jpg
#   inflating: cats-dogs/test/cats/cat_341.jpg
#   inflating: cats-dogs/test/cats/cat_342.jpg
#   inflating: cats-dogs/test/cats/cat_355.jpg
#   inflating: cats-dogs/test/cats/cat_358.jpg
#   inflating: cats-dogs/test/cats/cat_371.jpg
#   inflating: cats-dogs/test/cats/cat_375.jpg
#   inflating: cats-dogs/test/cats/cat_384.jpg
#   inflating: cats-dogs/test/cats/cat_395.jpg
#   inflating: cats-dogs/test/cats/cat_417.jpg
#   inflating: cats-dogs/test/cats/cat_418.jpg
#   inflating: cats-dogs/test/cats/cat_422.jpg
#   inflating: cats-dogs/test/cats/cat_430.jpg
#   inflating: cats-dogs/test/cats/cat_433.jpg
#   inflating: cats-dogs/test/cats/cat_446.jpg
#   inflating: cats-dogs/test/cats/cat_464.jpg
#   inflating: cats-dogs/test/cats/cat_468.jpg
#   inflating: cats-dogs/test/cats/cat_473.jpg
#   inflating: cats-dogs/test/cats/cat_496.jpg
#   inflating: cats-dogs/test/cats/cat_5.jpg
#   inflating: cats-dogs/test/cats/cat_504.jpg
#   inflating: cats-dogs/test/cats/cat_520.jpg
#   inflating: cats-dogs/test/cats/cat_523.jpg
#   inflating: cats-dogs/test/cats/cat_525.jpg
#   inflating: cats-dogs/test/cats/cat_528.jpg
#   inflating: cats-dogs/test/cats/cat_538.jpg
#   inflating: cats-dogs/test/cats/cat_542.jpg
#   inflating: cats-dogs/test/cats/cat_545.jpg
#   inflating: cats-dogs/test/cats/cat_551.jpg
#   inflating: cats-dogs/test/cats/cat_56.jpg
#   inflating: cats-dogs/test/cats/cat_564.jpg
#   inflating: cats-dogs/test/cats/cat_574.jpg
#   inflating: cats-dogs/test/cats/cat_575.jpg
#   inflating: cats-dogs/test/cats/cat_583.jpg
#   inflating: cats-dogs/test/cats/cat_585.jpg
#   inflating: cats-dogs/test/cats/cat_586.jpg
#   inflating: cats-dogs/test/cats/cat_587.jpg
#   inflating: cats-dogs/test/cats/cat_60.jpg
#   inflating: cats-dogs/test/cats/cat_605.jpg
#   inflating: cats-dogs/test/cats/cat_88.jpg
#   inflating: cats-dogs/test/cats/cat_94.jpg
#   inflating: cats-dogs/test/cats/cat_96.jpg
#    creating: cats-dogs/test/dogs/
#   inflating: cats-dogs/test/dogs/dog_114.jpg
#   inflating: cats-dogs/test/dogs/dog_123.jpg
#   inflating: cats-dogs/test/dogs/dog_124.jpg
#   inflating: cats-dogs/test/dogs/dog_130.jpg
#   inflating: cats-dogs/test/dogs/dog_141.jpg
#   inflating: cats-dogs/test/dogs/dog_142.jpg
#   inflating: cats-dogs/test/dogs/dog_147.jpg
#   inflating: cats-dogs/test/dogs/dog_150.jpg
#   inflating: cats-dogs/test/dogs/dog_155.jpg
#   inflating: cats-dogs/test/dogs/dog_159.jpg
#   inflating: cats-dogs/test/dogs/dog_168.jpg
#   inflating: cats-dogs/test/dogs/dog_173.jpg
#   inflating: cats-dogs/test/dogs/dog_177.jpg
#   inflating: cats-dogs/test/dogs/dog_181.jpg
#   inflating: cats-dogs/test/dogs/dog_191.jpg
#   inflating: cats-dogs/test/dogs/dog_194.jpg
#   inflating: cats-dogs/test/dogs/dog_196.jpg
#   inflating: cats-dogs/test/dogs/dog_197.jpg
#   inflating: cats-dogs/test/dogs/dog_211.jpg
#   inflating: cats-dogs/test/dogs/dog_213.jpg
#   inflating: cats-dogs/test/dogs/dog_219.jpg
#   inflating: cats-dogs/test/dogs/dog_227.jpg
#   inflating: cats-dogs/test/dogs/dog_229.jpg
#   inflating: cats-dogs/test/dogs/dog_236.jpg
#   inflating: cats-dogs/test/dogs/dog_237.jpg
#   inflating: cats-dogs/test/dogs/dog_240.jpg
#   inflating: cats-dogs/test/dogs/dog_244.jpg
#   inflating: cats-dogs/test/dogs/dog_258.jpg
#   inflating: cats-dogs/test/dogs/dog_28.jpg
#   inflating: cats-dogs/test/dogs/dog_283.jpg
#   inflating: cats-dogs/test/dogs/dog_302.jpg
#   inflating: cats-dogs/test/dogs/dog_303.jpg
#   inflating: cats-dogs/test/dogs/dog_313.jpg
#   inflating: cats-dogs/test/dogs/dog_327.jpg
#   inflating: cats-dogs/test/dogs/dog_344.jpg
#   inflating: cats-dogs/test/dogs/dog_354.jpg
#   inflating: cats-dogs/test/dogs/dog_355.jpg
#   inflating: cats-dogs/test/dogs/dog_360.jpg
#   inflating: cats-dogs/test/dogs/dog_364.jpg
#   inflating: cats-dogs/test/dogs/dog_369.jpg
#   inflating: cats-dogs/test/dogs/dog_377.jpg
#   inflating: cats-dogs/test/dogs/dog_380.jpg
#   inflating: cats-dogs/test/dogs/dog_398.jpg
#   inflating: cats-dogs/test/dogs/dog_415.jpg
#   inflating: cats-dogs/test/dogs/dog_421.jpg
#   inflating: cats-dogs/test/dogs/dog_43.jpg
#   inflating: cats-dogs/test/dogs/dog_44.jpg
#   inflating: cats-dogs/test/dogs/dog_442.jpg
#   inflating: cats-dogs/test/dogs/dog_443.jpg
#   inflating: cats-dogs/test/dogs/dog_461.jpg
#   inflating: cats-dogs/test/dogs/dog_462.jpg
#   inflating: cats-dogs/test/dogs/dog_464.jpg
#   inflating: cats-dogs/test/dogs/dog_472.jpg
#   inflating: cats-dogs/test/dogs/dog_476.jpg
#   inflating: cats-dogs/test/dogs/dog_482.jpg
#   inflating: cats-dogs/test/dogs/dog_517.jpg
#   inflating: cats-dogs/test/dogs/dog_518.jpg
#   inflating: cats-dogs/test/dogs/dog_519.jpg
#   inflating: cats-dogs/test/dogs/dog_520.jpg
#   inflating: cats-dogs/test/dogs/dog_521.jpg
#   inflating: cats-dogs/test/dogs/dog_522.jpg
#   inflating: cats-dogs/test/dogs/dog_528.jpg
#   inflating: cats-dogs/test/dogs/dog_534.jpg
#   inflating: cats-dogs/test/dogs/dog_536.jpg
#   inflating: cats-dogs/test/dogs/dog_551.jpg
#   inflating: cats-dogs/test/dogs/dog_563.jpg
#   inflating: cats-dogs/test/dogs/dog_59.jpg
#   inflating: cats-dogs/test/dogs/dog_68.jpg
#   inflating: cats-dogs/test/dogs/dog_75.jpg
#   inflating: cats-dogs/test/dogs/dog_89.jpg
#    creating: cats-dogs/train/
#    creating: cats-dogs/train/cats/
#   inflating: cats-dogs/train/cats/cat_10.jpg
#   inflating: cats-dogs/train/cats/cat_100.jpg
#   inflating: cats-dogs/train/cats/cat_101.jpg
#   inflating: cats-dogs/train/cats/cat_102.jpg
#   inflating: cats-dogs/train/cats/cat_103.jpg
#   inflating: cats-dogs/train/cats/cat_104.jpg
#   inflating: cats-dogs/train/cats/cat_11.jpg
#   inflating: cats-dogs/train/cats/cat_111.jpg
#   inflating: cats-dogs/train/cats/cat_12.jpg
#   inflating: cats-dogs/train/cats/cat_120.jpg
#   inflating: cats-dogs/train/cats/cat_123.jpg
#   inflating: cats-dogs/train/cats/cat_129.jpg
#   inflating: cats-dogs/train/cats/cat_13.jpg
#   inflating: cats-dogs/train/cats/cat_132.jpg
#   inflating: cats-dogs/train/cats/cat_133.jpg
#   inflating: cats-dogs/train/cats/cat_134.jpg
#   inflating: cats-dogs/train/cats/cat_137.jpg
#   inflating: cats-dogs/train/cats/cat_138.jpg
#   inflating: cats-dogs/train/cats/cat_139.jpg
#   inflating: cats-dogs/train/cats/cat_14.jpg
#   inflating: cats-dogs/train/cats/cat_141.jpg
#   inflating: cats-dogs/train/cats/cat_146.jpg
#   inflating: cats-dogs/train/cats/cat_148.jpg
#   inflating: cats-dogs/train/cats/cat_149.jpg
#   inflating: cats-dogs/train/cats/cat_15.jpg
#   inflating: cats-dogs/train/cats/cat_151.jpg
#   inflating: cats-dogs/train/cats/cat_152.jpg
#   inflating: cats-dogs/train/cats/cat_153.jpg
#   inflating: cats-dogs/train/cats/cat_159.jpg
#   inflating: cats-dogs/train/cats/cat_16.jpg
#   inflating: cats-dogs/train/cats/cat_160.jpg
#   inflating: cats-dogs/train/cats/cat_161.jpg
#   inflating: cats-dogs/train/cats/cat_163.jpg
#   inflating: cats-dogs/train/cats/cat_164.jpg
#   inflating: cats-dogs/train/cats/cat_165.jpg
#   inflating: cats-dogs/train/cats/cat_168.jpg
#   inflating: cats-dogs/train/cats/cat_169.jpg
#   inflating: cats-dogs/train/cats/cat_170.jpg
#   inflating: cats-dogs/train/cats/cat_172.jpg
#   inflating: cats-dogs/train/cats/cat_177.jpg
#   inflating: cats-dogs/train/cats/cat_179.jpg
#   inflating: cats-dogs/train/cats/cat_180.jpg
#   inflating: cats-dogs/train/cats/cat_183.jpg
#   inflating: cats-dogs/train/cats/cat_184.jpg
#   inflating: cats-dogs/train/cats/cat_189.jpg
#   inflating: cats-dogs/train/cats/cat_191.jpg
#   inflating: cats-dogs/train/cats/cat_194.jpg
#   inflating: cats-dogs/train/cats/cat_195.jpg
#   inflating: cats-dogs/train/cats/cat_198.jpg
#   inflating: cats-dogs/train/cats/cat_2.jpg
#   inflating: cats-dogs/train/cats/cat_200.jpg
#   inflating: cats-dogs/train/cats/cat_201.jpg
#   inflating: cats-dogs/train/cats/cat_202.jpg
#   inflating: cats-dogs/train/cats/cat_207.jpg
#   inflating: cats-dogs/train/cats/cat_208.jpg
#   inflating: cats-dogs/train/cats/cat_209.jpg
#   inflating: cats-dogs/train/cats/cat_21.jpg
#   inflating: cats-dogs/train/cats/cat_211.jpg
#   inflating: cats-dogs/train/cats/cat_213.jpg
#   inflating: cats-dogs/train/cats/cat_214.jpg
#   inflating: cats-dogs/train/cats/cat_215.jpg
#   inflating: cats-dogs/train/cats/cat_217.jpg
#   inflating: cats-dogs/train/cats/cat_218.jpg
#   inflating: cats-dogs/train/cats/cat_219.jpg
#   inflating: cats-dogs/train/cats/cat_220.jpg
#   inflating: cats-dogs/train/cats/cat_221.jpg
#   inflating: cats-dogs/train/cats/cat_222.jpg
#   inflating: cats-dogs/train/cats/cat_224.jpg
#   inflating: cats-dogs/train/cats/cat_225.jpg
#   inflating: cats-dogs/train/cats/cat_227.jpg
#   inflating: cats-dogs/train/cats/cat_228.jpg
#   inflating: cats-dogs/train/cats/cat_229.jpg
#   inflating: cats-dogs/train/cats/cat_230.jpg
#   inflating: cats-dogs/train/cats/cat_232.jpg
#   inflating: cats-dogs/train/cats/cat_235.jpg
#   inflating: cats-dogs/train/cats/cat_238.jpg
#   inflating: cats-dogs/train/cats/cat_24.jpg
#   inflating: cats-dogs/train/cats/cat_240.jpg
#   inflating: cats-dogs/train/cats/cat_243.jpg
#   inflating: cats-dogs/train/cats/cat_246.jpg
#   inflating: cats-dogs/train/cats/cat_247.jpg
#   inflating: cats-dogs/train/cats/cat_248.jpg
#   inflating: cats-dogs/train/cats/cat_253.jpg
#   inflating: cats-dogs/train/cats/cat_257.jpg
#   inflating: cats-dogs/train/cats/cat_26.jpg
#   inflating: cats-dogs/train/cats/cat_260.jpg
#   inflating: cats-dogs/train/cats/cat_261.jpg
#   inflating: cats-dogs/train/cats/cat_263.jpg
#   inflating: cats-dogs/train/cats/cat_265.jpg
#   inflating: cats-dogs/train/cats/cat_269.jpg
#   inflating: cats-dogs/train/cats/cat_27.jpg
#   inflating: cats-dogs/train/cats/cat_270.jpg
#   inflating: cats-dogs/train/cats/cat_271.jpg
#   inflating: cats-dogs/train/cats/cat_273.jpg
#   inflating: cats-dogs/train/cats/cat_274.jpg
#   inflating: cats-dogs/train/cats/cat_275.jpg
#   inflating: cats-dogs/train/cats/cat_276.jpg
#   inflating: cats-dogs/train/cats/cat_280.jpg
#   inflating: cats-dogs/train/cats/cat_284.jpg
#   inflating: cats-dogs/train/cats/cat_285.jpg
#   inflating: cats-dogs/train/cats/cat_289.jpg
#   inflating: cats-dogs/train/cats/cat_292.jpg
#   inflating: cats-dogs/train/cats/cat_293.jpg
#   inflating: cats-dogs/train/cats/cat_297.jpg
#   inflating: cats-dogs/train/cats/cat_298.jpg
#   inflating: cats-dogs/train/cats/cat_3.jpg
#   inflating: cats-dogs/train/cats/cat_303.jpg
#   inflating: cats-dogs/train/cats/cat_304.jpg
#   inflating: cats-dogs/train/cats/cat_307.jpg
#   inflating: cats-dogs/train/cats/cat_310.jpg
#   inflating: cats-dogs/train/cats/cat_311.jpg
#   inflating: cats-dogs/train/cats/cat_316.jpg
#   inflating: cats-dogs/train/cats/cat_317.jpg
#   inflating: cats-dogs/train/cats/cat_318.jpg
#   inflating: cats-dogs/train/cats/cat_320.jpg
#   inflating: cats-dogs/train/cats/cat_321.jpg
#   inflating: cats-dogs/train/cats/cat_325.jpg
#   inflating: cats-dogs/train/cats/cat_327.jpg
#   inflating: cats-dogs/train/cats/cat_329.jpg
#   inflating: cats-dogs/train/cats/cat_33.jpg
#   inflating: cats-dogs/train/cats/cat_330.jpg
#   inflating: cats-dogs/train/cats/cat_331.jpg
#   inflating: cats-dogs/train/cats/cat_333.jpg
#   inflating: cats-dogs/train/cats/cat_336.jpg
#   inflating: cats-dogs/train/cats/cat_34.jpg
#   inflating: cats-dogs/train/cats/cat_343.jpg
#   inflating: cats-dogs/train/cats/cat_344.jpg
#   inflating: cats-dogs/train/cats/cat_345.jpg
#   inflating: cats-dogs/train/cats/cat_348.jpg
#   inflating: cats-dogs/train/cats/cat_35.jpg
#   inflating: cats-dogs/train/cats/cat_350.jpg
#   inflating: cats-dogs/train/cats/cat_351.jpg
#   inflating: cats-dogs/train/cats/cat_352.jpg
#   inflating: cats-dogs/train/cats/cat_359.jpg
#   inflating: cats-dogs/train/cats/cat_361.jpg
#   inflating: cats-dogs/train/cats/cat_362.jpg
#   inflating: cats-dogs/train/cats/cat_363.jpg
#   inflating: cats-dogs/train/cats/cat_367.jpg
#   inflating: cats-dogs/train/cats/cat_369.jpg
#   inflating: cats-dogs/train/cats/cat_37.jpg
#   inflating: cats-dogs/train/cats/cat_370.jpg
#   inflating: cats-dogs/train/cats/cat_372.jpg
#   inflating: cats-dogs/train/cats/cat_373.jpg
#   inflating: cats-dogs/train/cats/cat_376.jpg
#   inflating: cats-dogs/train/cats/cat_377.jpg
#   inflating: cats-dogs/train/cats/cat_38.jpg
#   inflating: cats-dogs/train/cats/cat_380.jpg
#   inflating: cats-dogs/train/cats/cat_381.jpg
#   inflating: cats-dogs/train/cats/cat_385.jpg
#   inflating: cats-dogs/train/cats/cat_386.jpg
#   inflating: cats-dogs/train/cats/cat_387.jpg
#   inflating: cats-dogs/train/cats/cat_388.jpg
#   inflating: cats-dogs/train/cats/cat_39.jpg
#   inflating: cats-dogs/train/cats/cat_391.jpg
#   inflating: cats-dogs/train/cats/cat_393.jpg
#   inflating: cats-dogs/train/cats/cat_396.jpg
#   inflating: cats-dogs/train/cats/cat_397.jpg
#   inflating: cats-dogs/train/cats/cat_399.jpg
#   inflating: cats-dogs/train/cats/cat_4.jpg
#   inflating: cats-dogs/train/cats/cat_400.jpg
#   inflating: cats-dogs/train/cats/cat_402.jpg
#   inflating: cats-dogs/train/cats/cat_403.jpg
#   inflating: cats-dogs/train/cats/cat_405.jpg
#   inflating: cats-dogs/train/cats/cat_407.jpg
#   inflating: cats-dogs/train/cats/cat_408.jpg
#   inflating: cats-dogs/train/cats/cat_413.jpg
#   inflating: cats-dogs/train/cats/cat_414.jpg
#   inflating: cats-dogs/train/cats/cat_416.jpg
#   inflating: cats-dogs/train/cats/cat_419.jpg
#   inflating: cats-dogs/train/cats/cat_42.jpg
#   inflating: cats-dogs/train/cats/cat_420.jpg
#   inflating: cats-dogs/train/cats/cat_423.jpg
#   inflating: cats-dogs/train/cats/cat_426.jpg
#   inflating: cats-dogs/train/cats/cat_427.jpg
#   inflating: cats-dogs/train/cats/cat_428.jpg
#   inflating: cats-dogs/train/cats/cat_429.jpg
#   inflating: cats-dogs/train/cats/cat_43.jpg
#   inflating: cats-dogs/train/cats/cat_434.jpg
#   inflating: cats-dogs/train/cats/cat_435.jpg
#   inflating: cats-dogs/train/cats/cat_438.jpg
#   inflating: cats-dogs/train/cats/cat_440.jpg
#   inflating: cats-dogs/train/cats/cat_443.jpg
#   inflating: cats-dogs/train/cats/cat_445.jpg
#   inflating: cats-dogs/train/cats/cat_450.jpg
#   inflating: cats-dogs/train/cats/cat_452.jpg
#   inflating: cats-dogs/train/cats/cat_453.jpg
#   inflating: cats-dogs/train/cats/cat_455.jpg
#   inflating: cats-dogs/train/cats/cat_456.jpg
#   inflating: cats-dogs/train/cats/cat_46.jpg
#   inflating: cats-dogs/train/cats/cat_461.jpg
#   inflating: cats-dogs/train/cats/cat_463.jpg
#   inflating: cats-dogs/train/cats/cat_465.jpg
#   inflating: cats-dogs/train/cats/cat_466.jpg
#   inflating: cats-dogs/train/cats/cat_467.jpg
#   inflating: cats-dogs/train/cats/cat_469.jpg
#   inflating: cats-dogs/train/cats/cat_474.jpg
#   inflating: cats-dogs/train/cats/cat_482.jpg
#   inflating: cats-dogs/train/cats/cat_483.jpg
#   inflating: cats-dogs/train/cats/cat_485.jpg
#   inflating: cats-dogs/train/cats/cat_487.jpg
#   inflating: cats-dogs/train/cats/cat_489.jpg
#   inflating: cats-dogs/train/cats/cat_49.jpg
#   inflating: cats-dogs/train/cats/cat_490.jpg
#   inflating: cats-dogs/train/cats/cat_492.jpg
#   inflating: cats-dogs/train/cats/cat_493.jpg
#   inflating: cats-dogs/train/cats/cat_494.jpg
#   inflating: cats-dogs/train/cats/cat_495.jpg
#   inflating: cats-dogs/train/cats/cat_497.jpg
#   inflating: cats-dogs/train/cats/cat_498.jpg
#   inflating: cats-dogs/train/cats/cat_499.jpg
#   inflating: cats-dogs/train/cats/cat_50.jpg
#   inflating: cats-dogs/train/cats/cat_500.jpg
#   inflating: cats-dogs/train/cats/cat_505.jpg
#   inflating: cats-dogs/train/cats/cat_506.jpg
#   inflating: cats-dogs/train/cats/cat_508.jpg
#   inflating: cats-dogs/train/cats/cat_510.jpg
#   inflating: cats-dogs/train/cats/cat_511.jpg
#   inflating: cats-dogs/train/cats/cat_518.jpg
#   inflating: cats-dogs/train/cats/cat_519.jpg
#   inflating: cats-dogs/train/cats/cat_52.jpg
#   inflating: cats-dogs/train/cats/cat_524.jpg
#   inflating: cats-dogs/train/cats/cat_526.jpg
#   inflating: cats-dogs/train/cats/cat_53.jpg
#   inflating: cats-dogs/train/cats/cat_531.jpg
#   inflating: cats-dogs/train/cats/cat_532.jpg
#   inflating: cats-dogs/train/cats/cat_533.jpg
#   inflating: cats-dogs/train/cats/cat_535.jpg
#   inflating: cats-dogs/train/cats/cat_536.jpg
#   inflating: cats-dogs/train/cats/cat_54.jpg
#   inflating: cats-dogs/train/cats/cat_540.jpg
#   inflating: cats-dogs/train/cats/cat_543.jpg
#   inflating: cats-dogs/train/cats/cat_544.jpg
#   inflating: cats-dogs/train/cats/cat_546.jpg
#   inflating: cats-dogs/train/cats/cat_547.jpg
#   inflating: cats-dogs/train/cats/cat_548.jpg
#   inflating: cats-dogs/train/cats/cat_549.jpg
#   inflating: cats-dogs/train/cats/cat_553.jpg
#   inflating: cats-dogs/train/cats/cat_556.jpg
#   inflating: cats-dogs/train/cats/cat_557.jpg
#   inflating: cats-dogs/train/cats/cat_558.jpg
#   inflating: cats-dogs/train/cats/cat_559.jpg
#   inflating: cats-dogs/train/cats/cat_560.jpg
#   inflating: cats-dogs/train/cats/cat_565.jpg
#   inflating: cats-dogs/train/cats/cat_567.jpg
#   inflating: cats-dogs/train/cats/cat_569.jpg
#   inflating: cats-dogs/train/cats/cat_570.jpg
#   inflating: cats-dogs/train/cats/cat_573.jpg
#   inflating: cats-dogs/train/cats/cat_577.jpg
#   inflating: cats-dogs/train/cats/cat_58.jpg
#   inflating: cats-dogs/train/cats/cat_580.jpg
#   inflating: cats-dogs/train/cats/cat_581.jpg
#   inflating: cats-dogs/train/cats/cat_589.jpg
#   inflating: cats-dogs/train/cats/cat_59.jpg
#   inflating: cats-dogs/train/cats/cat_590.jpg
#   inflating: cats-dogs/train/cats/cat_591.jpg
#   inflating: cats-dogs/train/cats/cat_592.jpg
#   inflating: cats-dogs/train/cats/cat_6.jpg
#   inflating: cats-dogs/train/cats/cat_601.jpg
#   inflating: cats-dogs/train/cats/cat_602.jpg
#   inflating: cats-dogs/train/cats/cat_604.jpg
#   inflating: cats-dogs/train/cats/cat_61.jpg
#   inflating: cats-dogs/train/cats/cat_64.jpg
#   inflating: cats-dogs/train/cats/cat_66.jpg
#   inflating: cats-dogs/train/cats/cat_67.jpg
#   inflating: cats-dogs/train/cats/cat_69.jpg
#   inflating: cats-dogs/train/cats/cat_70.jpg
#   inflating: cats-dogs/train/cats/cat_74.jpg
#   inflating: cats-dogs/train/cats/cat_75.jpg
#   inflating: cats-dogs/train/cats/cat_77.jpg
#   inflating: cats-dogs/train/cats/cat_78.jpg
#   inflating: cats-dogs/train/cats/cat_80.jpg
#   inflating: cats-dogs/train/cats/cat_84.jpg
#   inflating: cats-dogs/train/cats/cat_87.jpg
#   inflating: cats-dogs/train/cats/cat_9.jpg
#   inflating: cats-dogs/train/cats/cat_93.jpg
#   inflating: cats-dogs/train/cats/cat_95.jpg
#   inflating: cats-dogs/train/cats/cat_97.jpg
#   inflating: cats-dogs/train/cats/cat_98.jpg
#    creating: cats-dogs/train/dogs/
#   inflating: cats-dogs/train/dogs/dog_0.jpg
#   inflating: cats-dogs/train/dogs/dog_10.jpg
#   inflating: cats-dogs/train/dogs/dog_100.jpg
#   inflating: cats-dogs/train/dogs/dog_102.jpg
#   inflating: cats-dogs/train/dogs/dog_103.jpg
#   inflating: cats-dogs/train/dogs/dog_106.jpg
#   inflating: cats-dogs/train/dogs/dog_109.jpg
#   inflating: cats-dogs/train/dogs/dog_11.jpg
#   inflating: cats-dogs/train/dogs/dog_110.jpg
#   inflating: cats-dogs/train/dogs/dog_113.jpg
#   inflating: cats-dogs/train/dogs/dog_116.jpg
#   inflating: cats-dogs/train/dogs/dog_120.jpg
#   inflating: cats-dogs/train/dogs/dog_122.jpg
#   inflating: cats-dogs/train/dogs/dog_125.jpg
#   inflating: cats-dogs/train/dogs/dog_128.jpg
#   inflating: cats-dogs/train/dogs/dog_129.jpg
#   inflating: cats-dogs/train/dogs/dog_13.jpg
#   inflating: cats-dogs/train/dogs/dog_133.jpg
#   inflating: cats-dogs/train/dogs/dog_136.jpg
#   inflating: cats-dogs/train/dogs/dog_138.jpg
#   inflating: cats-dogs/train/dogs/dog_139.jpg
#   inflating: cats-dogs/train/dogs/dog_140.jpg
#   inflating: cats-dogs/train/dogs/dog_144.jpg
#   inflating: cats-dogs/train/dogs/dog_145.jpg
#   inflating: cats-dogs/train/dogs/dog_15.jpg
#   inflating: cats-dogs/train/dogs/dog_151.jpg
#   inflating: cats-dogs/train/dogs/dog_152.jpg
#   inflating: cats-dogs/train/dogs/dog_154.jpg
#   inflating: cats-dogs/train/dogs/dog_156.jpg
#   inflating: cats-dogs/train/dogs/dog_162.jpg
#   inflating: cats-dogs/train/dogs/dog_164.jpg
#   inflating: cats-dogs/train/dogs/dog_165.jpg
#   inflating: cats-dogs/train/dogs/dog_167.jpg
#   inflating: cats-dogs/train/dogs/dog_171.jpg
#   inflating: cats-dogs/train/dogs/dog_175.jpg
#   inflating: cats-dogs/train/dogs/dog_178.jpg
#   inflating: cats-dogs/train/dogs/dog_182.jpg
#   inflating: cats-dogs/train/dogs/dog_186.jpg
#   inflating: cats-dogs/train/dogs/dog_188.jpg
#   inflating: cats-dogs/train/dogs/dog_192.jpg
#   inflating: cats-dogs/train/dogs/dog_193.jpg
#   inflating: cats-dogs/train/dogs/dog_195.jpg
#   inflating: cats-dogs/train/dogs/dog_199.jpg
#   inflating: cats-dogs/train/dogs/dog_200.jpg
#   inflating: cats-dogs/train/dogs/dog_202.jpg
#   inflating: cats-dogs/train/dogs/dog_203.jpg
#   inflating: cats-dogs/train/dogs/dog_204.jpg
#   inflating: cats-dogs/train/dogs/dog_205.jpg
#   inflating: cats-dogs/train/dogs/dog_206.jpg
#   inflating: cats-dogs/train/dogs/dog_207.jpg
#   inflating: cats-dogs/train/dogs/dog_208.jpg
#   inflating: cats-dogs/train/dogs/dog_209.jpg
#   inflating: cats-dogs/train/dogs/dog_21.jpg
#   inflating: cats-dogs/train/dogs/dog_212.jpg
#   inflating: cats-dogs/train/dogs/dog_214.jpg
#   inflating: cats-dogs/train/dogs/dog_216.jpg
#   inflating: cats-dogs/train/dogs/dog_217.jpg
#   inflating: cats-dogs/train/dogs/dog_218.jpg
#   inflating: cats-dogs/train/dogs/dog_22.jpg
#   inflating: cats-dogs/train/dogs/dog_220.jpg
#   inflating: cats-dogs/train/dogs/dog_221.jpg
#   inflating: cats-dogs/train/dogs/dog_224.jpg
#   inflating: cats-dogs/train/dogs/dog_226.jpg
#   inflating: cats-dogs/train/dogs/dog_23.jpg
#   inflating: cats-dogs/train/dogs/dog_230.jpg
#   inflating: cats-dogs/train/dogs/dog_231.jpg
#   inflating: cats-dogs/train/dogs/dog_232.jpg
#   inflating: cats-dogs/train/dogs/dog_234.jpg
#   inflating: cats-dogs/train/dogs/dog_238.jpg
#   inflating: cats-dogs/train/dogs/dog_239.jpg
#   inflating: cats-dogs/train/dogs/dog_241.jpg
#   inflating: cats-dogs/train/dogs/dog_243.jpg
#   inflating: cats-dogs/train/dogs/dog_247.jpg
#   inflating: cats-dogs/train/dogs/dog_249.jpg
#   inflating: cats-dogs/train/dogs/dog_251.jpg
#   inflating: cats-dogs/train/dogs/dog_253.jpg
#   inflating: cats-dogs/train/dogs/dog_256.jpg
#   inflating: cats-dogs/train/dogs/dog_259.jpg
#   inflating: cats-dogs/train/dogs/dog_26.jpg
#   inflating: cats-dogs/train/dogs/dog_260.jpg
#   inflating: cats-dogs/train/dogs/dog_261.jpg
#   inflating: cats-dogs/train/dogs/dog_262.jpg
#   inflating: cats-dogs/train/dogs/dog_266.jpg
#   inflating: cats-dogs/train/dogs/dog_267.jpg
#   inflating: cats-dogs/train/dogs/dog_268.jpg
#   inflating: cats-dogs/train/dogs/dog_269.jpg
#   inflating: cats-dogs/train/dogs/dog_270.jpg
#   inflating: cats-dogs/train/dogs/dog_272.jpg
#   inflating: cats-dogs/train/dogs/dog_273.jpg
#   inflating: cats-dogs/train/dogs/dog_277.jpg
#   inflating: cats-dogs/train/dogs/dog_281.jpg
#   inflating: cats-dogs/train/dogs/dog_286.jpg
#   inflating: cats-dogs/train/dogs/dog_287.jpg
#   inflating: cats-dogs/train/dogs/dog_29.jpg
#   inflating: cats-dogs/train/dogs/dog_290.jpg
#   inflating: cats-dogs/train/dogs/dog_291.jpg
#   inflating: cats-dogs/train/dogs/dog_292.jpg
#   inflating: cats-dogs/train/dogs/dog_293.jpg
#   inflating: cats-dogs/train/dogs/dog_294.jpg
#   inflating: cats-dogs/train/dogs/dog_295.jpg
#   inflating: cats-dogs/train/dogs/dog_296.jpg
#   inflating: cats-dogs/train/dogs/dog_298.jpg
#   inflating: cats-dogs/train/dogs/dog_299.jpg
#   inflating: cats-dogs/train/dogs/dog_3.jpg
#   inflating: cats-dogs/train/dogs/dog_30.jpg
#   inflating: cats-dogs/train/dogs/dog_301.jpg
#   inflating: cats-dogs/train/dogs/dog_305.jpg
#   inflating: cats-dogs/train/dogs/dog_306.jpg
#   inflating: cats-dogs/train/dogs/dog_31.jpg
#   inflating: cats-dogs/train/dogs/dog_315.jpg
#   inflating: cats-dogs/train/dogs/dog_317.jpg
#   inflating: cats-dogs/train/dogs/dog_318.jpg
#   inflating: cats-dogs/train/dogs/dog_32.jpg
#   inflating: cats-dogs/train/dogs/dog_320.jpg
#   inflating: cats-dogs/train/dogs/dog_321.jpg
#   inflating: cats-dogs/train/dogs/dog_322.jpg
#   inflating: cats-dogs/train/dogs/dog_323.jpg
#   inflating: cats-dogs/train/dogs/dog_324.jpg
#   inflating: cats-dogs/train/dogs/dog_325.jpg
#   inflating: cats-dogs/train/dogs/dog_33.jpg
#   inflating: cats-dogs/train/dogs/dog_331.jpg
#   inflating: cats-dogs/train/dogs/dog_332.jpg
#   inflating: cats-dogs/train/dogs/dog_333.jpg
#   inflating: cats-dogs/train/dogs/dog_334.jpg
#   inflating: cats-dogs/train/dogs/dog_335.jpg
#   inflating: cats-dogs/train/dogs/dog_337.jpg
#   inflating: cats-dogs/train/dogs/dog_338.jpg
#   inflating: cats-dogs/train/dogs/dog_341.jpg
#   inflating: cats-dogs/train/dogs/dog_342.jpg
#   inflating: cats-dogs/train/dogs/dog_343.jpg
#   inflating: cats-dogs/train/dogs/dog_345.jpg
#   inflating: cats-dogs/train/dogs/dog_347.jpg
#   inflating: cats-dogs/train/dogs/dog_349.jpg
#   inflating: cats-dogs/train/dogs/dog_35.jpg
#   inflating: cats-dogs/train/dogs/dog_350.jpg
#   inflating: cats-dogs/train/dogs/dog_351.jpg
#   inflating: cats-dogs/train/dogs/dog_358.jpg
#   inflating: cats-dogs/train/dogs/dog_359.jpg
#   inflating: cats-dogs/train/dogs/dog_361.jpg
#   inflating: cats-dogs/train/dogs/dog_363.jpg
#   inflating: cats-dogs/train/dogs/dog_365.jpg
#   inflating: cats-dogs/train/dogs/dog_367.jpg
#   inflating: cats-dogs/train/dogs/dog_368.jpg
#   inflating: cats-dogs/train/dogs/dog_37.jpg
#   inflating: cats-dogs/train/dogs/dog_371.jpg
#   inflating: cats-dogs/train/dogs/dog_375.jpg
#   inflating: cats-dogs/train/dogs/dog_376.jpg
#   inflating: cats-dogs/train/dogs/dog_378.jpg
#   inflating: cats-dogs/train/dogs/dog_381.jpg
#   inflating: cats-dogs/train/dogs/dog_389.jpg
#   inflating: cats-dogs/train/dogs/dog_39.jpg
#   inflating: cats-dogs/train/dogs/dog_391.jpg
#   inflating: cats-dogs/train/dogs/dog_392.jpg
#   inflating: cats-dogs/train/dogs/dog_393.jpg
#   inflating: cats-dogs/train/dogs/dog_4.jpg
#   inflating: cats-dogs/train/dogs/dog_401.jpg
#   inflating: cats-dogs/train/dogs/dog_402.jpg
#   inflating: cats-dogs/train/dogs/dog_403.jpg
#   inflating: cats-dogs/train/dogs/dog_404.jpg
#   inflating: cats-dogs/train/dogs/dog_405.jpg
#   inflating: cats-dogs/train/dogs/dog_407.jpg
#   inflating: cats-dogs/train/dogs/dog_408.jpg
#   inflating: cats-dogs/train/dogs/dog_409.jpg
#   inflating: cats-dogs/train/dogs/dog_412.jpg
#   inflating: cats-dogs/train/dogs/dog_414.jpg
#   inflating: cats-dogs/train/dogs/dog_417.jpg
#   inflating: cats-dogs/train/dogs/dog_418.jpg
#   inflating: cats-dogs/train/dogs/dog_419.jpg
#   inflating: cats-dogs/train/dogs/dog_423.jpg
#   inflating: cats-dogs/train/dogs/dog_427.jpg
#   inflating: cats-dogs/train/dogs/dog_428.jpg
#   inflating: cats-dogs/train/dogs/dog_429.jpg
#   inflating: cats-dogs/train/dogs/dog_432.jpg
#   inflating: cats-dogs/train/dogs/dog_433.jpg
#   inflating: cats-dogs/train/dogs/dog_435.jpg
#   inflating: cats-dogs/train/dogs/dog_436.jpg
#   inflating: cats-dogs/train/dogs/dog_437.jpg
#   inflating: cats-dogs/train/dogs/dog_438.jpg
#   inflating: cats-dogs/train/dogs/dog_440.jpg
#   inflating: cats-dogs/train/dogs/dog_441.jpg
#   inflating: cats-dogs/train/dogs/dog_444.jpg
#   inflating: cats-dogs/train/dogs/dog_445.jpg
#   inflating: cats-dogs/train/dogs/dog_446.jpg
#   inflating: cats-dogs/train/dogs/dog_447.jpg
#   inflating: cats-dogs/train/dogs/dog_448.jpg
#   inflating: cats-dogs/train/dogs/dog_45.jpg
#   inflating: cats-dogs/train/dogs/dog_450.jpg
#   inflating: cats-dogs/train/dogs/dog_451.jpg
#   inflating: cats-dogs/train/dogs/dog_452.jpg
#   inflating: cats-dogs/train/dogs/dog_458.jpg
#   inflating: cats-dogs/train/dogs/dog_466.jpg
#   inflating: cats-dogs/train/dogs/dog_468.jpg
#   inflating: cats-dogs/train/dogs/dog_47.jpg
#   inflating: cats-dogs/train/dogs/dog_471.jpg
#   inflating: cats-dogs/train/dogs/dog_473.jpg
#   inflating: cats-dogs/train/dogs/dog_474.jpg
#   inflating: cats-dogs/train/dogs/dog_475.jpg
#   inflating: cats-dogs/train/dogs/dog_478.jpg
#   inflating: cats-dogs/train/dogs/dog_479.jpg
#   inflating: cats-dogs/train/dogs/dog_480.jpg
#   inflating: cats-dogs/train/dogs/dog_483.jpg
#   inflating: cats-dogs/train/dogs/dog_484.jpg
#   inflating: cats-dogs/train/dogs/dog_485.jpg
#   inflating: cats-dogs/train/dogs/dog_487.jpg
#   inflating: cats-dogs/train/dogs/dog_489.jpg
#   inflating: cats-dogs/train/dogs/dog_490.jpg
#   inflating: cats-dogs/train/dogs/dog_492.jpg
#   inflating: cats-dogs/train/dogs/dog_494.jpg
#   inflating: cats-dogs/train/dogs/dog_496.jpg
#   inflating: cats-dogs/train/dogs/dog_50.jpg
#   inflating: cats-dogs/train/dogs/dog_501.jpg
#   inflating: cats-dogs/train/dogs/dog_502.jpg
#   inflating: cats-dogs/train/dogs/dog_504.jpg
#   inflating: cats-dogs/train/dogs/dog_505.jpg
#   inflating: cats-dogs/train/dogs/dog_509.jpg
#   inflating: cats-dogs/train/dogs/dog_51.jpg
#   inflating: cats-dogs/train/dogs/dog_512.jpg
#   inflating: cats-dogs/train/dogs/dog_513.jpg
#   inflating: cats-dogs/train/dogs/dog_514.jpg
#   inflating: cats-dogs/train/dogs/dog_523.jpg
#   inflating: cats-dogs/train/dogs/dog_525.jpg
#   inflating: cats-dogs/train/dogs/dog_529.jpg
#   inflating: cats-dogs/train/dogs/dog_532.jpg
#   inflating: cats-dogs/train/dogs/dog_533.jpg
#   inflating: cats-dogs/train/dogs/dog_535.jpg
#   inflating: cats-dogs/train/dogs/dog_54.jpg
#   inflating: cats-dogs/train/dogs/dog_540.jpg
#   inflating: cats-dogs/train/dogs/dog_541.jpg
#   inflating: cats-dogs/train/dogs/dog_543.jpg
#   inflating: cats-dogs/train/dogs/dog_545.jpg
#   inflating: cats-dogs/train/dogs/dog_546.jpg
#   inflating: cats-dogs/train/dogs/dog_549.jpg
#   inflating: cats-dogs/train/dogs/dog_550.jpg
#   inflating: cats-dogs/train/dogs/dog_552.jpg
#   inflating: cats-dogs/train/dogs/dog_553.jpg
#   inflating: cats-dogs/train/dogs/dog_554.jpg
#   inflating: cats-dogs/train/dogs/dog_556.jpg
#   inflating: cats-dogs/train/dogs/dog_558.jpg
#   inflating: cats-dogs/train/dogs/dog_559.jpg
#   inflating: cats-dogs/train/dogs/dog_56.jpg
#   inflating: cats-dogs/train/dogs/dog_560.jpg
#   inflating: cats-dogs/train/dogs/dog_564.jpg
#   inflating: cats-dogs/train/dogs/dog_566.jpg
#   inflating: cats-dogs/train/dogs/dog_57.jpg
#   inflating: cats-dogs/train/dogs/dog_570.jpg
#   inflating: cats-dogs/train/dogs/dog_571.jpg
#   inflating: cats-dogs/train/dogs/dog_572.jpg
#   inflating: cats-dogs/train/dogs/dog_576.jpg
#   inflating: cats-dogs/train/dogs/dog_579.jpg
#   inflating: cats-dogs/train/dogs/dog_580.jpg
#   inflating: cats-dogs/train/dogs/dog_582.jpg
#   inflating: cats-dogs/train/dogs/dog_583.jpg
#   inflating: cats-dogs/train/dogs/dog_589.jpg
#   inflating: cats-dogs/train/dogs/dog_591.jpg
#   inflating: cats-dogs/train/dogs/dog_596.jpg
#   inflating: cats-dogs/train/dogs/dog_62.jpg
#   inflating: cats-dogs/train/dogs/dog_67.jpg
#   inflating: cats-dogs/train/dogs/dog_69.jpg
#   inflating: cats-dogs/train/dogs/dog_7.jpg
#   inflating: cats-dogs/train/dogs/dog_70.jpg
#   inflating: cats-dogs/train/dogs/dog_72.jpg
#   inflating: cats-dogs/train/dogs/dog_74.jpg
#   inflating: cats-dogs/train/dogs/dog_76.jpg
#   inflating: cats-dogs/train/dogs/dog_77.jpg
#   inflating: cats-dogs/train/dogs/dog_78.jpg
#   inflating: cats-dogs/train/dogs/dog_8.jpg
#   inflating: cats-dogs/train/dogs/dog_80.jpg
#   inflating: cats-dogs/train/dogs/dog_82.jpg
#   inflating: cats-dogs/train/dogs/dog_84.jpg
#   inflating: cats-dogs/train/dogs/dog_85.jpg
#   inflating: cats-dogs/train/dogs/dog_86.jpg
#   inflating: cats-dogs/train/dogs/dog_9.jpg
#   inflating: cats-dogs/train/dogs/dog_90.jpg
#   inflating: cats-dogs/train/dogs/dog_92.jpg
#   inflating: cats-dogs/train/dogs/dog_93.jpg
#   inflating: cats-dogs/train/dogs/dog_97.jpg
#   inflating: cats-dogs/train/dogs/dog_98.jpg
#   inflating: cats-dogs/train/dogs/dog_99.jpg

# %%
train_dir = '/content/cats-dogs/train'
test_dir = '/content/cats-dogs/test'

# %% [markdown]
# # Create Datasets and DataLoaders

# %%
import os

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str,
    test_dir: str,
    transform: transforms.Compose,
    batch_size: int,
    num_workers: int=NUM_WORKERS
):

  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
# Create image size
IMG_SIZE = 224

# Create transform pipeline manually
manual_transforms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
])
print(f"Manually created transforms: {manual_transforms}")
# Out:
# Manually created transforms: Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
# )

# %%
BATCH_SIZE = 32

# Create data loaders
train_dataloader, test_dataloader, class_names = create_dataloaders(
    train_dir=train_dir,
    test_dir=test_dir,
    transform=manual_transforms,
    batch_size=BATCH_SIZE
)

train_dataloader, test_dataloader, class_names
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7fbfcd6aac80>,
#  <torch.utils.data.dataloader.DataLoader at 0x7fbfcd6aa170>,
#  ['cats', 'dogs'])

# %%
# Let's visualize a image in order to know if data is loaded properly or not

# Get a batch of images
image_batch, label_batch = next(iter(train_dataloader))

# Get a single image from the batch
image, label = image_batch[0], label_batch[0]

# View the batch shapes
print(image.shape, label)

# Plot image with matplotlib
plt.imshow(image.permute(1, 2, 0)) # rearrange image dimensions to suit matplotlib [color_channels, height, width] -> [height, width, color_channels]
plt.title(class_names[label])
plt.axis(False);
# Out:
# torch.Size([3, 224, 224]) tensor(0)

# %% [markdown]
# * Turn an image into patches
# * Flatten the patch feature maps into a single dimension
# * Convert the output into Desried output (flattened 2D patches): (196, 768) -> N×(P2⋅C) #Current shape: (1, 768, 196)

# %%
class PatchEmbedding(nn.Module):
    """Turns a 2D input image into a 1D sequence learnable embedding vector.

    Args:
        in_channels (int): Number of color channels for the input images. Defaults to 3.
        patch_size (int): Size of patches to convert input image into. Defaults to 16.
        embedding_dim (int): Size of embedding to turn image into. Defaults to 768.
    """

    def __init__(self, in_channels:int=3, patch_size:int=16, embedding_dim:int=768):
        super().__init__()

        # Create a layer to turn an image into patches
        self.patcher = nn.Conv2d(in_channels=in_channels,
                                 out_channels=embedding_dim,
                                 kernel_size=patch_size,
                                 stride=patch_size,
                                 padding=0)

        # Create a layer to flatten the patch feature maps into a single dimension
        self.flatten = nn.Flatten(start_dim=2, end_dim=3) # only flatten the feature map dimensions into a single vector


    def forward(self, x):
        # Create assertion to check that inputs are the correct shape
        image_resolution = x.shape[-1]
        assert image_resolution % patch_size == 0, f"Input image size must be divisble by patch size, image shape: {image_resolution}, patch size: {patch_size}"

        # Perform the forward pass
        x_patched = self.patcher(x)
        x_flattened = self.flatten(x_patched)

        # Make sure the output shape has the right order
        return x_flattened.permute(0, 2, 1) # adjust so the embedding is on the final dimension [batch_size, P^2•C, N] -> [batch_size, N, P^2•C]

# %% [markdown]
# # PatchEmbedding layer

# %%
# Let's test it on single image
patch_size =16

# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)



set_seeds()

# Create an instance of patch embedding layer
patchify = PatchEmbedding(in_channels=3,
                          patch_size=16,
                          embedding_dim=768)

# Pass a single image through
print(f"Input image shape: {image.unsqueeze(0).shape}")
print(image.shape)
patch_embedded_image = patchify(image.unsqueeze(0)) # add an extra batch dimension on the 0th index, otherwise will error
print(f"Output patch embedding shape: {patch_embedded_image.shape}")
# Out:
# Input image shape: torch.Size([1, 3, 224, 224])
# torch.Size([3, 224, 224])
# Output patch embedding shape: torch.Size([1, 196, 768])

# %%
print(patch_embedded_image)
print(f"Patch embedding shape: {patch_embedded_image.shape} -> [batch_size, number_of_patches, embedding_dimension]")
# Out:
# tensor([[[-0.7944,  0.2201, -0.2243,  ...,  0.6101, -0.3528,  0.2671],
#          [-0.8075,  0.1981, -0.1971,  ...,  0.6227, -0.3516,  0.2815],
#          [-0.8008,  0.2156, -0.2377,  ...,  0.6190, -0.3578,  0.2781],
#          ...,
#          [-0.4425,  0.1460, -0.1349,  ...,  0.3278, -0.1834,  0.1413],
#          [-0.4846,  0.1527, -0.1535,  ...,  0.3631, -0.1961,  0.1651],
#          [-0.4489,  0.1715, -0.1801,  ...,  0.3811, -0.2183,  0.1433]]],
#        grad_fn=<PermuteBackward0>)
# Patch embedding shape: torch.Size([1, 196, 768]) -> [batch_size, number_of_patches, embedding_dimension]

# %%
# Now add the the learnable class embedding and position embeddings
# From start to positional encoding: All in 1 cell

set_seeds()

# 1. Set patch size
patch_size = 16

# 2. Print shape of original image tensor and get the image dimensions
print(f"Image tensor shape: {image.shape}")
height, width = image.shape[1], image.shape[2]

# 3. Get image tensor and add batch dimension
x = image.unsqueeze(0)
print(f"Input image with batch dimension shape: {x.shape}")

# 4. Create patch embedding layer
patch_embedding_layer = PatchEmbedding(in_channels=3,
                                       patch_size=patch_size,
                                       embedding_dim=768)

# 5. Pass image through patch embedding layer
patch_embedding = patch_embedding_layer(x)
print(f"Patching embedding shape: {patch_embedding.shape}")



# 6. Create class token embedding
batch_size = patch_embedding.shape[0]
embedding_dimension = patch_embedding.shape[-1]
class_token = nn.Parameter(torch.ones(batch_size, 1, embedding_dimension),
                           requires_grad=True) # make sure it's learnable
print(f"Class token embedding shape: {class_token.shape}")

# 7. Prepend class token embedding to patch embedding
patch_embedding_class_token = torch.cat((class_token, patch_embedding), dim=1)
print(f"Patch embedding with class token shape: {patch_embedding_class_token.shape}")

# 8. Create position embedding
number_of_patches = int((height * width) / patch_size**2)
position_embedding = nn.Parameter(torch.ones(1, number_of_patches+1, embedding_dimension),
                                  requires_grad=True) # make sure it's learnable


# 9. Add position embedding to patch embedding with class token
patch_and_position_embedding = patch_embedding_class_token + position_embedding
print(f"Patch and position embedding shape: {patch_and_position_embedding.shape}")
#patch_and_position_embedding

print(patch_embedding_class_token)  #1 is added in the beginning of each
# Out:
# Image tensor shape: torch.Size([3, 224, 224])
# Input image with batch dimension shape: torch.Size([1, 3, 224, 224])
# Patching embedding shape: torch.Size([1, 196, 768])
# Class token embedding shape: torch.Size([1, 1, 768])
# Patch embedding with class token shape: torch.Size([1, 197, 768])
# Patch and position embedding shape: torch.Size([1, 197, 768])
# tensor([[[ 1.0000,  1.0000,  1.0000,  ...,  1.0000,  1.0000,  1.0000],
#          [-0.7944,  0.2201, -0.2243,  ...,  0.6101, -0.3528,  0.2671],
#          [-0.8075,  0.1981, -0.1971,  ...,  0.6227, -0.3516,  0.2815],
#          ...,
#          [-0.4425,  0.1460, -0.1349,  ...,  0.3278, -0.1834,  0.1413],
#          [-0.4846,  0.1527, -0.1535,  ...,  0.3631, -0.1961,  0.1651],
#          [-0.4489,  0.1715, -0.1801,  ...,  0.3811, -0.2183,  0.1433]]],
#        grad_fn=<CatBackward0>)

# %% [markdown]
# # Model

# %% [markdown]
# **We can implement the MSA layer in PyTorch with torch.nn.MultiheadAttention() with the parameters:**
#
# Multi-Head Self Attention (MSA) - **torch.nn.MultiheadAttention()**
#
# *   embed_dim - the embedding dimension D
# *   num_heads - how many attention heads to use (this is where the term "multihead" comes from)
# *   dropout - whether or not to apply dropout to the attention layer
# *   batch_first - does our batch dimension come first? (yes it does)

# %%
class MultiheadSelfAttentionBlock(nn.Module):
    """Creates a multi-head self-attention block ("MSA block" for short).
    """

    def __init__(self,
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 attn_dropout:float=0): # doesn't look like the paper uses any dropout in MSABlocks
        super().__init__()
        self.layer_norm = nn.LayerNorm(normalized_shape=embedding_dim)
        self.multihead_attn = nn.MultiheadAttention(embed_dim=embedding_dim,
                                                    num_heads=num_heads,
                                                    dropout=attn_dropout,
                                                    batch_first=True) # does our batch dimension come first?

    def forward(self, x):
        x = self.layer_norm(x)
        attn_output, _ = self.multihead_attn(query=x, # query embeddings
                                             key=x, # key embeddings
                                             value=x, # value embeddings
                                             need_weights=False) # do we need the weights or just the layer outputs?
        return attn_output

# %%
class MLPBlock(nn.Module):
    """Creates a layer normalized multilayer perceptron block ("MLP block" for short)."""

    def __init__(self,
                 embedding_dim:int=768, # Hidden Size D from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 dropout:float=0.1): # Dropout from Table 3 for ViT-Base
        super().__init__()


        self.layer_norm = nn.LayerNorm(normalized_shape=embedding_dim)

        self.mlp = nn.Sequential(
            nn.Linear(in_features=embedding_dim,
                      out_features=mlp_size),
            nn.GELU(), # "The MLP contains two layers with a GELU non-linearity (section 3.1)."
            nn.Dropout(p=dropout),
            nn.Linear(in_features=mlp_size, # needs to take same in_features as out_features of layer above
                      out_features=embedding_dim), # take back to embedding_dim
            nn.Dropout(p=dropout) # "Dropout, when used, is applied after every dense layer.."
        )

    def forward(self, x):
        x = self.layer_norm(x)
        x = self.mlp(x)
        return x

# %% [markdown]
# **Creating a Transformer Encoder by combining our custom made layers**

# %%
class TransformerEncoderBlock(nn.Module):
    def __init__(self,
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 mlp_dropout:float=0.1, # Amount of dropout for dense layers from Table 3 for ViT-Base
                 attn_dropout:float=0): # Amount of dropout for attention layers
        super().__init__()

        # Create MSA block
        self.msa_block = MultiheadSelfAttentionBlock(embedding_dim=embedding_dim,
                                                     num_heads=num_heads,
                                                     attn_dropout=attn_dropout)

        # Create MLP block
        self.mlp_block =  MLPBlock(embedding_dim=embedding_dim,
                                   mlp_size=mlp_size,
                                   dropout=mlp_dropout)

    def forward(self, x):
        # Create residual connection for MSA block (add the input to the output)
        x =  self.msa_block(x) + x
        # Create residual connection for MLP block (add the input to the output)
        x = self.mlp_block(x) + x

        return x

# %% [markdown]
# **build a vision transformer**

# %%
class ViT(nn.Module):
    """Creates a Vision Transformer architecture with ViT-Base hyperparameters by default."""

    def __init__(self,
                 img_size:int=224, # Training resolution from Table 3 in ViT paper
                 in_channels:int=3, # Number of channels in input image
                 patch_size:int=16, # Patch size
                 num_transformer_layers:int=12, # Layers from Table 1 for ViT-Base
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 attn_dropout:float=0, # Dropout for attention projection
                 mlp_dropout:float=0.1, # Dropout for dense/MLP layers
                 embedding_dropout:float=0.1, # Dropout for patch and position embeddings
                 num_classes:int=1000): # Default for ImageNet but can customize this
        super().__init__() # don't forget the super().__init__()!

        # 3. Make the image size is divisble by the patch size
        assert img_size % patch_size == 0, f"Image size must be divisible by patch size, image size: {img_size}, patch size: {patch_size}."

        # 4. Calculate number of patches (height * width/patch^2)
        self.num_patches = (img_size * img_size) // patch_size**2

        # 5. Create learnable class embedding (needs to go at front of sequence of patch embeddings)
        self.class_embedding = nn.Parameter(data=torch.randn(1, 1, embedding_dim),
                                            requires_grad=True)

        # 6. Create learnable position embedding
        self.position_embedding = nn.Parameter(data=torch.randn(1, self.num_patches+1, embedding_dim),
                                               requires_grad=True)

        # 7. Create embedding dropout value
        self.embedding_dropout = nn.Dropout(p=embedding_dropout)

        # 8. Create patch embedding layer
        self.patch_embedding = PatchEmbedding(in_channels=in_channels,
                                              patch_size=patch_size,
                                              embedding_dim=embedding_dim)

        # 9. Create Transformer Encoder blocks (we can stack Transformer Encoder blocks using nn.Sequential())
        # Note: The "*" means "all"
        self.transformer_encoder = nn.Sequential(*[TransformerEncoderBlock(embedding_dim=embedding_dim,
                                                                            num_heads=num_heads,
                                                                            mlp_size=mlp_size,
                                                                            mlp_dropout=mlp_dropout) for _ in range(num_transformer_layers)])

        # 10. Create classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(normalized_shape=embedding_dim),
            nn.Linear(in_features=embedding_dim,
                      out_features=num_classes)
        )

    # 11. Create a forward() method
    def forward(self, x):

        # 12. Get batch size
        batch_size = x.shape[0]

        # 13. Create class token embedding and expand it to match the batch size (equation 1)
        class_token = self.class_embedding.expand(batch_size, -1, -1) # "-1" means to infer the dimension (try this line on its own)

        # 14. Create patch embedding (equation 1)
        x = self.patch_embedding(x)

        # 15. Concat class embedding and patch embedding (equation 1)
        x = torch.cat((class_token, x), dim=1)

        # 16. Add position embedding to patch embedding (equation 1)
        x = self.position_embedding + x

        # 17. Run embedding dropout (Appendix B.1)
        x = self.embedding_dropout(x)

        # 18. Pass patch, position and class embedding through transformer encoder layers (equations 2 & 3)
        x = self.transformer_encoder(x)

        # 19. Put 0 index logit through classifier (equation 4)
        x = self.classifier(x[:, 0]) # run on each sample in a batch at 0 index

        return x

# %% [markdown]
# # Train

# %%
vit = ViT(num_classes=len(class_names))

# %% [markdown]
# **Training engine**

# %%
import torch

from tqdm.auto import tqdm
from typing import Dict, List, Tuple

def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device) -> Tuple[float, float]:
    """Trains a PyTorch model for a single epoch.

    Turns a target PyTorch model to training mode and then
    runs through all of the required training steps (forward
    pass, loss calculation, optimizer step).

    Args:
    model: A PyTorch model to be trained.
    dataloader: A DataLoader instance for the model to be trained on.
    loss_fn: A PyTorch loss function to minimize.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A tuple of training loss and training accuracy metrics.
    In the form (train_loss, train_accuracy). For example:

    (0.1112, 0.8743)
    """
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device) -> Tuple[float, float]:
    """Tests a PyTorch model for a single epoch.

    Turns a target PyTorch model to "eval" mode and then performs
    a forward pass on a testing dataset.

    Args:
    model: A PyTorch model to be tested.
    dataloader: A DataLoader instance for the model to be tested on.
    loss_fn: A PyTorch loss function to calculate loss on the test data.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A tuple of testing loss and testing accuracy metrics.
    In the form (test_loss, test_accuracy). For example:

    (0.0223, 0.8985)
    """
    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device) -> Dict[str, List]:
    """Trains and tests a PyTorch model.

    Passes a target PyTorch models through train_step() and test_step()
    functions for a number of epochs, training and testing the model
    in the same epoch loop.

    Calculates, prints and stores evaluation metrics throughout.

    Args:
    model: A PyTorch model to be trained and tested.
    train_dataloader: A DataLoader instance for the model to be trained on.
    test_dataloader: A DataLoader instance for the model to be tested on.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    loss_fn: A PyTorch loss function to calculate loss on both datasets.
    epochs: An integer indicating how many epochs to train for.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A dictionary of training and testing loss as well as training and
    testing accuracy metrics. Each metric has a value in a list for
    each epoch.
    In the form: {train_loss: [...],
              train_acc: [...],
              test_loss: [...],
              test_acc: [...]}
    For example if training for epochs=2:
             {train_loss: [2.0616, 1.0537],
              train_acc: [0.3945, 0.3945],
              test_loss: [1.2641, 1.5706],
              test_acc: [0.3400, 0.2973]}
    """
    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }

    # Make sure model on target device
    model.to(device)

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                          dataloader=train_dataloader,
                                          loss_fn=loss_fn,
                                          optimizer=optimizer,
                                          device=device)
        test_loss, test_acc = test_step(model=model,
          dataloader=test_dataloader,
          loss_fn=loss_fn,
          device=device)

        # Print out what's happening
        print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
        )

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    # Return the filled results at the end of the epochs
    return results

# %%
# Setup the optimizer to optimize our ViT model parameters using hyperparameters from the ViT paper
optimizer = torch.optim.Adam(params=vit.parameters(),
                             lr=3e-3,
                             betas=(0.9, 0.999),
                             weight_decay=0.3)

# Setup the loss function for multi-class classification
loss_fn = torch.nn.CrossEntropyLoss()

# Set the seeds
set_seeds()

# Train the model and save the training results to a dictionary
results = train(model=vit,
                       train_dataloader=train_dataloader,
                       test_dataloader=test_dataloader,
                       optimizer=optimizer,
                       loss_fn=loss_fn,
                       epochs=10,
                device=torch.device("cuda" if torch.cuda.is_available() else "cpu"))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.8765 | train_acc: 0.5012 | test_loss: 0.6882 | test_acc: 0.5625
# Epoch: 2 | train_loss: 0.7144 | train_acc: 0.5116 | test_loss: 0.6882 | test_acc: 0.5625
# Epoch: 3 | train_loss: 0.7126 | train_acc: 0.4919 | test_loss: 0.7011 | test_acc: 0.4375
# Epoch: 4 | train_loss: 0.7035 | train_acc: 0.5069 | test_loss: 0.6859 | test_acc: 0.5625
# Epoch: 5 | train_loss: 0.7124 | train_acc: 0.4641 | test_loss: 0.6945 | test_acc: 0.5625
# Epoch: 6 | train_loss: 0.7225 | train_acc: 0.5098 | test_loss: 0.6873 | test_acc: 0.5625
# Epoch: 7 | train_loss: 0.7058 | train_acc: 0.4867 | test_loss: 0.6906 | test_acc: 0.5625
# Epoch: 8 | train_loss: 0.7032 | train_acc: 0.4462 | test_loss: 0.7184 | test_acc: 0.4375
# Epoch: 9 | train_loss: 0.7062 | train_acc: 0.5000 | test_loss: 0.6879 | test_acc: 0.5625
# Epoch: 10 | train_loss: 0.7185 | train_acc: 0.4601 | test_loss: 0.7010 | test_acc: 0.4375

# %% [markdown]
# # Predictions

# %%
from typing import List, Tuple
from PIL import Image
import requests

# %%
def pred_and_plot_image(
    model: torch.nn.Module,
    class_names: List[str],
    image_path: str,
    image_size: Tuple[int, int] = (224, 224),
    transform: torchvision.transforms = None,
    device: torch.device = device,
):


    # Open image
    img = Image.open(image_path)

    # Create transformation for image (if one doesn't exist)
    if transform is not None:
        image_transform = transform
    else:
        image_transform = transforms.Compose(
            [
                transforms.Resize(image_size),
                transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
                ),
            ]
        )

    ### Predict on image ###
    model.to(device)

    # Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
        # Transform and add an extra dimension to image (model requires samples in [batch_size, color_channels, height, width])
        transformed_image = image_transform(img).unsqueeze(dim=0)

        # Make a prediction on image with an extra dimension and send it to the target device
        target_image_pred = model(transformed_image.to(device))

    # Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)
    print(target_image_pred_label)
    # Plot image with predicted label and probability
    plt.figure()
    plt.imshow(img)
    plt.title(
        f"Pred: {class_names[target_image_pred_label]} | Prob: {target_image_pred_probs.max():.3f}"
    )
    plt.axis(False)

# %%
# Setup custom image path
custom_image_path = "/content/prediction-img/test-4.jpg"

# Predict on custom image
pred_and_plot_image(model=vit,
                    image_path=custom_image_path,
                    class_names=class_names)
# Out:
# tensor([0], device='cuda:0')
